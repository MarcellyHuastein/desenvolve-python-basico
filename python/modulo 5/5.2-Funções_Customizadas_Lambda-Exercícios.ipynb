# %% [markdown]
# # Módulo 5 - Funções
#
# ## Aulas 5.2 - Funções Customizadas e 5.4 Funções ```lambda```

# %% [markdown]
# ### Q1.
#
# - Sabendo que o código a seguir calcula o fatorial de n, escreva uma função chamada ```fatorial()``` que recebe um inteiro ```n``` como parâmetro e retorna o resultado do fatorial de ```n```.
# - No programa principal, peça ao usuário o valor de ```n```, chame a sua função e imprima o retorno.
#
# ```python
# fat = 1
# for i in range(1, n+1):
#     fat *= i
# ```

# %%
## Crie aqui a função fatorial()
## lembre-se de executar a célula para que 
## a função passe a existir e possa ser chamada

# %%
## Escreva aqui o programa principal e execute a célula
def fatorial(n):
    """
    Calcula o fatorial de um número inteiro n.
    
    Parameters:
    n (int): O número para o qual o fatorial deve ser calculado.
    
    Returns:
    int: O fatorial de n.
    """
    # Inicializa o resultado do fatorial
    fat = 1
    # Calcula o fatorial de n
    for i in range(1, n + 1):
        fat *= i
    return fat

# Programa principal
def main():
    # Solicita ao usuário o valor de n
    n = int(input("Digite um número inteiro para calcular o fatorial: "))
    # Chama a função fatorial e obtém o resultado
    resultado = fatorial(n)
    # Imprime o resultado
    print(f"O fatorial de {n} é {resultado}")

# Executa o programa principal
if __name__ == "__main__":
    main()

# %% [markdown]
# ### Q2.
#
# - Escreva uma função em Python chamada ```soma_quadrados``` que recebe dois números como parâmetros e retorna a soma dos seus quadrados.
# - No programa principal solicite ao usuário que insira dois números e utilize a função para exibir a soma dos quadrados.

# %%
## Crie aqui a função soma_quadrados()

# %%
## Escreva aqui o programa principal e execute a célula
def soma_quadrados(a, b):
    """
    Calcula a soma dos quadrados de dois números.
    
    Parameters:
    a (int or float): O primeiro número.
    b (int or float): O segundo número.
    
    Returns:
    int or float: A soma dos quadrados de a e b.
    """
    return a**2 + b**2

# Programa principal
def main():
    # Solicita ao usuário que insira dois números
    num1 = float(input("Digite o primeiro número: "))
    num2 = float(input("Digite o segundo número: "))
    
    # Chama a função soma_quadrados e obtém o resultado
    resultado = soma_quadrados(num1, num2)
    
    # Exibe o resultado
    print(f"A soma dos quadrados de {num1} e {num2} é {resultado}")

# Executa o programa principal
if __name__ == "__main__":
    main()

# %% [markdown]
# ### Q3.
#
# - Crie uma função em Python chamada ```soma_digitos``` que recebe um número inteiro como parâmetro e retorna a soma dos seus dígitos. Por exemplo, para o número 123, a função deve retornar 6, $(1 + 2 + 3)$.
#     - O desafio aqui é separar os dígitos de um número inteiro usando operações aritméticas <br> <br>
#
# - No programa principal solicite ao usuário que insira um número e utilize a função ```soma_digitos``` para calcular e exibir a soma dos seus dígitos.

# %%
## Crie aqui a função soma_digitos()

# %%
## Escreva aqui o programa principal e execute a célula
def soma_digitos(n):
    """
    Calcula a soma dos dígitos de um número inteiro.

    Parameters:
    n (int): O número cujo soma dos dígitos deve ser calculada.
    
    Returns:
    int: A soma dos dígitos de n.
    """
    # Garante que o número é positivo para simplificar a soma dos dígitos
    n = abs(n)
    
    soma = 0
    while n > 0:
        # Adiciona o último dígito à soma
        soma += n % 10
        # Remove o último dígito
        n //= 10

    return soma

# Programa principal
def main():
    # Solicita ao usuário que insira um número
    numero = int(input("Digite um número inteiro: "))
    
    # Chama a função soma_digitos e obtém o resultado
    resultado = soma_digitos(numero)
    
    # Exibe o resultado
    print(f"A soma dos dígitos de {numero} é {resultado}")

# Executa o programa principal
if __name__ == "__main__":
    main()

# %% [markdown]
# ### Q4.
#
# - Crie a função ```inverteValor()``` que recebe um inteiro de qualquer tamanho e retorna esse valor invertido usando apenas operações aritméticas
# - Crie a função ```verificaInverso()``` que recebe o valor original e o valor invertido e retorna verdadeiro se ambos forem igualmente par ou igualmente ímpar. Retorne falso caso contrário.
# - No programa principal, peça um valor do usuário e imprima o retorno de ambas as funções.

# %%
## Crie aqui as funções inverteValor() e verificaInverso()

# %%
## Escreva aqui o programa principal e execute a célula
def inverteValor(n):
    """
    Inverte o valor de um número inteiro usando apenas operações aritméticas.

    Parameters:
    n (int): O número a ser invertido.
    
    Returns:
    int: O número invertido.
    """
    invertido = 0
    while n > 0:
        digito = n % 10  # Obtém o último dígito
        invertido = invertido * 10 + digito  # Adiciona o dígito ao número invertido
        n //= 10  # Remove o último dígito do número original
    return invertido

def verificaInverso(original, invertido):
    """
    Verifica se o valor original e o valor invertido são ambos pares ou ambos ímpares.

    Parameters:
    original (int): O valor original.
    invertido (int): O valor invertido.
    
    Returns:
    bool: True se ambos forem igualmente pares ou igualmente ímpares, False caso contrário.
    """
    def eh_par(x):
        return x % 2 == 0
    
    return eh_par(original) == eh_par(invertido)

# Programa principal
def main():
    # Solicita ao usuário que insira um número
    numero = int(input("Digite um número inteiro: "))
    
    # Chama a função inverteValor e obtém o resultado
    numero_invertido = inverteValor(numero)
    
    # Chama a função verificaInverso e obtém o resultado
    resultado_verificacao = verificaInverso(numero, numero_invertido)
    
    # Exibe os resultados
    print(f"O valor invertido de {numero} é {numero_invertido}")
    print(f"O valor original e o invertido são ambos pares ou ambos ímpares? {resultado_verificacao}")

# Executa o programa principal
if __name__ == "__main__":
    main()

# %% [markdown]
# ### Q5.
#
# Você está desenvolvendo um programa para auxiliar em cálculos de geometria básica. Crie as seguintes funções:
# - A função ```calcula_perimetro_triangulo()``` que recebe três inteiros correspondentes aos lados de um triângulo e retorna o perímetro do triângulo, ou seja, a soma dos seus lados.
# - A função ```calcula_perimetro_circulo()``` que recebe um inteiro referente ao raio do círculo e retorna o perímetro do círculo, dado por $2 \pi r$. Use a constante $\pi$ da biblioteca ```math```.
# - A função ```calcula_perimetro_retangulo()``` que possui um parâmetro obrigatório ```lado1``` e um opcional ```lado2```, ambos inteiros. Se o valor opcional não for fornecido, significa que se trata de um quadrado. Sua função deve calcular e retornar o perímetro do retângulo, ou seja, a soma de seus lados.
#     - Para o quadrado, é dado por $4 \times lado1$
#     - Para o retângulo é dado por $2 \times lado1 + 2 \times lado2$
#
# - No programa principal apresente um menu com as opções disponíveis do seu sistema e uma quarta opção ```Sair```. Solicite ao usuário a opção desejada, solicite as entradas correspondentes à opção escolhida, invoque a respective função e apresente o seu retorno. Seu programa deve retornar ao menu até que o usuário escolha a opção ```Sair```
#
# Exemplo de interação:
# ```
# 1 - Calcular perímetro triângulo
# 2 - Calcular perímetro círculo
# 3 - Calcular perímetro retângulo
# 4 - Sair
#
# Opção: 1
# Digite os três lados do triângulo:
# 3
# 4
# 5
# O perímetro é: 12
#
# 1 - Calcular perímetro triângulo
# 2 - Calcular perímetro círculo
# 3 - Calcular perímetro retângulo
# 4 - Sair
#
# Opção: 3
# Informe os dois lados do retângulo. Se for um quadrado, digite 0 para o segundo valor:
# 5
# 0
# O perímetro é: 20
#
# 1 - Calcular perímetro triângulo
# 2 - Calcular perímetro círculo
# 3 - Calcular perímetro retângulo
# 4 - Sair
#
# Opção: 4
# ```

# %%
## Crie aqui as funções

# %%
## Escreva aqui o programa principal 
import math

def calcula_perimetro_triangulo(lado1, lado2, lado3):
    """
    Calcula o perímetro de um triângulo.
    
    Parameters:
    lado1 (int): O comprimento do primeiro lado.
    lado2 (int): O comprimento do segundo lado.
    lado3 (int): O comprimento do terceiro lado.
    
    Returns:
    int: O perímetro do triângulo.
    """
    return lado1 + lado2 + lado3

def calcula_perimetro_circulo(raio):
    """
    Calcula o perímetro (circunferência) de um círculo.
    
    Parameters:
    raio (int): O raio do círculo.
    
    Returns:
    float: O perímetro do círculo.
    """
    return 2 * math.pi * raio

def calcula_perimetro_retangulo(lado1, lado2=0):
    """
    Calcula o perímetro de um retângulo. Se o segundo lado não for fornecido, calcula o perímetro de um quadrado.
    
    Parameters:
    lado1 (int): O comprimento do primeiro lado.
    lado2 (int, opcional): O comprimento do segundo lado. Se não fornecido, considera-se um quadrado.
    
    Returns:
    int: O perímetro do retângulo ou quadrado.
    """
    if lado2 == 0:
        # Caso seja um quadrado
        return 4 * lado1
    else:
        # Caso seja um retângulo
        return 2 * (lado1 + lado2)

def main():
    while True:
        print("\n1 - Calcular perímetro triângulo")
        print("2 - Calcular perímetro círculo")
        print("3 - Calcular perímetro retângulo")
        print("4 - Sair")
        
        opcao = int(input("Opção: "))
        
        if opcao == 1:
            print("Digite os três lados do triângulo:")
            lado1 = int(input())
            lado2 = int(input())
            lado3 = int(input())
            resultado = calcula_perimetro_triangulo(lado1, lado2, lado3)
            print(f"O perímetro é: {resultado}")
        
        elif opcao == 2:
            raio = int(input("Digite o raio do círculo: "))
            resultado = calcula_perimetro_circulo(raio)
            print(f"O perímetro é: {resultado:.2f}")
        
        elif opcao == 3:
            print("Informe os dois lados do retângulo. Se for um quadrado, digite 0 para o segundo valor:")
            lado1 = int(input())
            lado2 = int(input())
            resultado = calcula_perimetro_retangulo(lado1, lado2)
            print(f"O perímetro é: {resultado}")
        
        elif opcao == 4:
            print("Saindo...")
            break
        
        else:
            print("Opção inválida. Tente novamente.")

if __name__ == "__main__":
    main()

# %% [markdown]
# ## Funções ```lambda```

# %% [markdown]
# ### Q6.
#
# Crie uma função lambda para verificar se um número é par ou ímpar. Em seguida, solicite ao usuário um número indefinidos de valores (até que o usuário digite 0). Para cada valor de entrada, informe se é par ou ímpar.
#
# Exemplo de interação:
# ```
# Digite os valores que deseja verificar a paridade (digite 0 para finalizar a entrada de dados):
# 3
# ímpar
# 8
# par
# 12
# par
# 5
# ímpar
# 7ímpar
# ```

# %%
# Função lambda para verificar se um número é par ou ímpar
verifica_paridade = lambda x: 'par' if x % 2 == 0 else 'ímpar'

def main():
    print("Digite os valores que deseja verificar a paridade (digite 0 para finalizar a entrada de dados):")
    
    while True:
        # Solicita ao usuário que insira um número
        numero = int(input())
        
        # Se o número for 0, encerra a entrada de dados
        if numero == 0:
            break
        
        # Usa a função lambda para verificar a paridade e exibe o resultado
        resultado = verifica_paridade(numero)
        print(resultado)

# Executa o programa principal
if __name__ == "__main__":
    main()

# %% [markdown]
# ### Q7.
#
# Escreva um programa que pergunte ao usuário qual operação ele deseja: maior ou menor.
# Em seguida leia uma quantidade indefinida de valores do usuário, até que o usuário digite o valor zero.
# Apresente ao final o maior ou menor dos valores digitados de acordo com a escolha do usuário.
#
# **Sua solução deve incluir pelo menos uma função ```lambda```**
#
# Exemplo de interação:
# ```
# Opções: (1) maior ou (2) menor?
# Opção: 1
#
# Digite os valores de entrada. Digite 0 para finalizar a entrada de valores.
# 4
# 12
# 15
# 1
# 0
#
# O maior valor é: 15
# ```

# %%
## Escreva aqui o programa principal 
def main():
    # Define as funções lambda para encontrar o maior e o menor valor
    maior = lambda x, y: x if x > y else y
    menor = lambda x, y: x if x < y else y

    # Solicita ao usuário que escolha a operação
    print("Opções: (1) maior ou (2) menor?")
    opcao = int(input("Opção: "))

    # Inicializa as variáveis para armazenar o resultado
    resultado = None

    if opcao == 1:
        print("Digite os valores de entrada. Digite 0 para finalizar a entrada de valores.")
        while True:
            valor = int(input())
            if valor == 0:
                break
            if resultado is None:
                resultado = valor
            else:
                resultado = maior(resultado, valor)
        print(f"O maior valor é: {resultado}")

    elif opcao == 2:
        print("Digite os valores de entrada. Digite 0 para finalizar a entrada de valores.")
        while True:
            valor = int(input())
            if valor == 0:
                break
            if resultado is None:
                resultado = valor
            else:
                resultado = menor(resultado, valor)
        print(f"O menor valor é: {resultado}")

    else:
        print("Opção inválida.")

# Executa o programa principal
if __name__ == "__main__":
    main()
